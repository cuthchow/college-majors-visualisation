# %%
import plotly.express as px
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../data/wiki_movies dummy.csv')
data
# Out:
#      year  month   day                      title         director  \
# 0    2000      1   8.0                     Pasrah     Yusof Haslam
# 1    2000      4   6.0                 Mimpi Moon    Shuhaimi Baba
# 2    2000      5  25.0               Senario Lagi    Aziz M. Osman
# 3    2000      6  29.0             Anaknya Sazali              NaN
# 4    2000      8  31.0             Leftenan Adnan    Aziz M. Osman
# ..    ...    ...   ...                        ...              ...
# 805  2020      3  19.0            Eye On The Ball     Chen Yih Wen
# 806  2020      3  26.0                  Town Mall     Eizlan Yusof
# 807  2020      3  26.0  Kenderaan Berat Ikut Kiri      Jefry Talib
# 808  2020      3  26.0                     Escape  Ikhwansha Hazer
# 809  2020      4   2.0               Takut Ke Tak  Muzzamer Rahman
#
#                                                   cast                genre  \
# 0    Erra Fazira, Norman Hakim, Wilma Muhammad, Abb...      Drama / Romance
# ...

# %%
fig = px.scatter(data, x="budget", y="box_office", color="gender_director")
fig.show()
# Out:
# <div>                            <div id="632938be-1cb8-4d0f-bf72-7af9dc0f16ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("632938be-1cb8-4d0f-bf72-7af9dc0f16ea")) {                    Plotly.newPlot(                        "632938be-1cb8-4d0f-bf72-7af9dc0f16ea",                        [{"hovertemplate": "gender_director=Female<br>budget=%{x}<br>box_office=%{y}<extra></extra>", "legendgroup": "Female", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Female", "orientation": "v", "showlegend": true, "type": "scatter", "x": [3322833, 3830290, 5549935, 9360828, 3777594, 998377, 6698607, 4124639, 415103, 4185924, 7456988, 1263515, 2762251, 8839728, 9823379, 5892201, 2502803, 1149350, 8128466, 2948484, 9008716, 6539905,
# ...
