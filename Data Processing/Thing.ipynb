# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt


# %matplotlib inline

# %%
df = pd.read_csv('Meteorite_Landings.csv')

# %%
df.dtypes
# Out:
# name            object
# id               int64
# nametype        object
# recclass        object
# mass (g)       float64
# fall            object
# year            object
# reclat         float64
# reclong        float64
# GeoLocation     object
# dtype: object

# %%
df
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation
# ...

# %%
datethingy = '%d/%m/%Y %I:%M:%S %p'

# %%
df['year'].str.slice(6, 10)
# Out:
# 0        1880
# 1        1951
# 2        1952
# 3        1976
# 4        1902
#          ...
# 45711    1990
# 45712    1999
# 45713    1939
# 45714    2003
# 45715    1976
# Name: year, Length: 45716, dtype: object

# %%
df = df[df.year.str.slice(6, 10).isna() == False]

# %%
df = df[df.year.str.slice(6,10).astype(int) > 1690]

# %%
df['year'] = pd.to_datetime(df.year, format = datethingy)

# %%
df.year
# Out:
# 0       1880-01-01
# 1       1951-01-01
# 2       1952-01-01
# 3       1976-01-01
# 4       1902-01-01
#            ...
# 45711   1990-01-01
# 45712   1999-01-01
# 45713   1939-01-01
# 45714   2003-01-01
# 45715   1976-01-01
# Name: year, Length: 45403, dtype: datetime64[ns]

# %%
df
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#             year    reclat    reclong             GeoLocation
# ...

# %%
dt = df['year'].max() - df['year'].min()

# %%
df[df.year.dt.year == 2101]
# Out:
#                         name     id nametype recclass  mass (g)   fall  \
# 30682  Northwest Africa 7701  57150    Valid      CK6      55.0  Found
#
#             year  reclat  reclong GeoLocation
# 30682 2101-01-01     0.0      0.0  (0.0, 0.0)

# %%
df
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#             year    reclat    reclong             GeoLocation
# ...

# %%
df['mass'] = df['mass (g)'] / 1000

# %%
df
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation  \
# ...

# %%
df['dayOfWeek'] = df.year.dt.dayofweek

# %%
df
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#             year    reclat    reclong             GeoLocation      mass  \
# ...

# %%
df.name.apply(lambda x: len(x.split()))
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 45711    2
# 45712    1
# 45713    1
# 45714    1
# 45715    2
# Name: name, Length: 45403, dtype: int64
